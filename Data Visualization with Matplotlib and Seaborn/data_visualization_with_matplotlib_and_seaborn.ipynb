# %% [markdown]
# # Data Visualization using Maplotlib and Seaborn

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# Notice this we also include the special command **%matplotlib inline** to ensure that plots are shown and embedded within the Jupyter Notebook itself. Without this command, sometimes plots my show up in pop-up windows.

# %% [markdown]
# ## Line Chart
#
# Line charts are one of the simplest and most widely used data visualization techniques. A line chart displays information as a series of data points or makers, connected by straight lines. You can customize the shape, size, color and other aesthetic elements of the makers and lines for better visual clarity.

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %% [markdown]
# We can visualize how the yield of apples changes over time using a line chart. To draw a line chart, we can use the **plt.plot** function.

# %%
plt.plot(yield_apples)

# %%
plt.plot(yield_apples);

# %% [markdown]
# Let's enhance this plot step-by-step to make it more informative and beautiful.

# %% [markdown]
# ### Customizing the X-Axis
#
# The X-axis of the plot currently shows list element indexes 0 to 5. The plot would be more informative if we could show the year for which the data is being plotted. We can do this by two arguments **plt.plot**.

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(years, yield_apples)

# %% [markdown]
# ### Axis Labels
#
# We can add labels to the axes to show what each axis represents using the **plt.xlabel** and **plt.ylabel**.

# %%
plt.plot(years, yield_apples)
plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)");

# %% [markdown]
# ### Plotting Multiple Lines
#
# It's really easy to plot multiple lines in the same graph. Just invoke  the **plt.plot** function multiple times. Let's compare the yields of apples vs oranges in Kato

# %%
years = range(2000, 2012)
apples = [0.895, 0.90, 0.91, 0.921, 0.938, 0.94, 0.945, 0.978, 0.98, 0.982, 0.987, 0.989]
oranges = [0.958, 0.978, 0.95, 0.9, 0.87, 0.82, 0.80, 0.75, 0.72, 0.645, 0.62, 0.59]

# %%
plt.plot(years, apples)
plt.plot(years, oranges)

plt.xlabel("Year")
plt.ylabel("Yield (tone per hectare)")
# Out:
# Text(0, 0.5, 'Yield (tone per hectare)')

# %% [markdown]
# ### Chart  Title and Legend
#
# To differentiate between multiple lines, we can include a legend within the graph using the **plt.legend** function. We also give the entire chart a title using the **plt.title** function.

# %%
plt.plot(years, apples, label = "Apples")
plt.plot(years, oranges, label = "Oranges")

plt.xlabel("Year")
plt.ylabel("Yield (tone per hectare)")

plt.title("Crop yields in Kanto")
plt.legend()

# %% [markdown]
# ### Line Markers
#
# We can also show markers for the data points on each line using the **marker** argument of **plt.plot**. Matplotlib supports many different types of markers like circle, cross, square, diamond etc.

# %%
plt.plot(years, apples, label = "Apples", marker = "o")
plt.plot(years, oranges, label = "Oranges", marker = "x")

plt.xlabel("Year")
plt.ylabel("Yield (tone per hectare)")

plt.title("Crop yields in Kanto")
plt.legend()

# %% [markdown]
# ### Styling Lines and Markers
#
# The **plt.plot** function supports many arguments for styling lines and markers:
#
# + **color** or **c**: set the color of the line
# + **linestyle** or **ls**: choose between a solid or dashed line
# + **linewidth** or **lw**: set the width of a line
# + **markersize** or **ms**: set the size of markers
# + **markeredgecolor** or **mec**: set the edge color for markers
# + **markeredgewidth** or **mew**: set the edge width for makers
# + **markerfacecolor** or **mfc**: set the fill color for makers
#
# Check out the documentation for **py.plot** to learn more: https://matplotlib.org/stable/api/index.html

# %%
plt.plot(years, apples, label = "Apples", marker = "s", c = "b", ls = "-", lw = 2, ms = 5)
plt.plot(years, oranges, label = "Oranges", marker = "o", c = "r", ls = "--", lw = 3, ms = 10)

plt.xlabel("Year")
plt.ylabel("Yield (tone per hectare)")

plt.title("Crop yields in Kanto")
plt.legend();

# %% [markdown]
# The **fmt** argument provides a shorthand for specifying the line style, marker and line color. It can be provided as the third argument to **plt.plot**.

# %% [markdown]
#     fmt = [marker][line][color]

# %%
plt.plot(years, apples, "s-b", label = "Apples")
plt.plot(years, oranges, "o--r", label = "Oranges")

plt.xlabel("Year")
plt.ylabel("Yield (tone per hectare)")

plt.title("Crop yields in Kanto")
plt.legend();

# %% [markdown]
# If no line sytle is specified in **fmt**, only makers are drawn.

# %%
plt.plot(years, oranges, "or")
plt.title("Yield of Oranges (tons per hectare)")
# Out:
# Text(0.5, 1.0, 'Yield of Oranges (tons per hectare)')

# %% [markdown]
# ### Changing the Figure Size
#
# You can use the **plt.figure** function to change the size of the figure.

# %%
plt.figure(figsize = (3, 3))

plt.plot(years, oranges, "or")
plt.title("Yield of Oranges (tons per hectare)")
# Out:
# Text(0.5, 1.0, 'Yield of Oranges (tons per hectare)')

# %% [markdown]
# ### Improving Default Styles using Seaborn
#
# An easy way to  make your charts look beautiful is to use some default styles provided in the **Seaborn** library. These can be applied globally using the **sns.set_style** function. You can see a full list of predefined styles here: https://seaborn.pydata.org/generated/seaborn.set_style.html

# %%
sns.set_style("whitegrid")

# %%
plt.plot(years, apples, "s-b", label = "Apples")
plt.plot(years, oranges, "o--r", label = "Oranges")

plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)")

plt.title("Crop Yields in Kanto")
plt.legend()

# %%
sns.set_style("darkgrid")

# %%
plt.plot(years, apples, "s-b", label = "Apples")
plt.plot(years, oranges, "o--r", label = "Oranges")

plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)")

plt.title("Crop Yields in Kanto")
plt.legend()

# %% [markdown]
# You can also edit default styles directly by modifying the **matplotlib.rcParams** dictionary. Learn more: https://matplotlib.org/3.2.1/tutorials/introductory/customizing.html#matplotlib-rcparams

# %%
import matplotlib

# %%
matplotlib.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#EAEAF2',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
matplotlib.rcParams["font.size"] = 14
matplotlib.rcParams["figure.figsize"] = (8, 8)
matplotlib.rcParams["figure.facecolor"] = "#00000000"

# %% [markdown]
# ## Scatter Plot
#
# In a scatter plot, the values of 2 variables are plotted as points on a 2-dimensional grid. Additionally, you can also use a third variable to determine the size or color of the points. Let's try out an examples.
#
# The **iris flower dataset** provides samples measurements of sepals an petals for 3 species of flowers. The iris dataset is included with the Seaborn library, and you can be loaded as a Pandas data frame

# %%
# Laod data into a Pandas DataFrame

# %%
flowers_df = sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# Let's try to visualize the relationship between sepal length and sepal width. Our first instinct might be to create a line chart using **plt.plot**. Howover, the output is not very informative as there are too many combinations of the two properties within the dataset and there doesn't seem to be simple relationship between them.

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width)

# %% [markdown]
# We can use a scatter plot to visualize how sepal length & width vary using the **scatterplot** function from **seaborn** (imported as **sns**)

# %%
sns.scatterplot(x = flowers_df.sepal_length, y = flowers_df.sepal_width)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ### Adding Hues
#
# Notice how the points in the above plot seem to form distinct clusters with some outliers. We can color the dots using the flower species as a **hue**. We can also make the points larger using the **s** argument.

# %%
sns.scatterplot(x = flowers_df.sepal_length, 
                y = flowers_df.sepal_width, 
                hue = flowers_df.species, 
                s = 100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# Adding hues makes the plot more informative. We can immediately tell that flowers of the Setosa species have a smaller sepal length but higher sepal widths, while the opposite holds true for Virginica species.

# %% [markdown]
# ### Customizing Seaborn Figures
#
# Since Seaborn uses Matplotlib's plotting functions internally, we can use functions like **plt.figure** and **plt.title** to modify the figure.

# %%
plt.figure(figsize = (20, 8))
plt.title("Sepal Dimensions")

sns.scatterplot(x = flowers_df.sepal_length, 
                y = flowers_df.sepal_width, 
                hue = flowers_df.species, 
                s = 100)
# Out:
# <AxesSubplot:title={'center':'Sepal Dimensions'}, xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ### Plotting using Pandas DataFrame
#
# Seaborn has in-built support for Pandas data frames. Instead of passing each columns as a series you can also pass column names and use the **data** argument to pass the data frame.

# %%
plt.title("Sepal Dimensions")
sns.scatterplot(x = "sepal_length", 
                y = "sepal_width", 
                data = flowers_df, 
                hue = "species", 
                s = 100)
# Out:
# <AxesSubplot:title={'center':'Sepal Dimensions'}, xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## Histogram
#
# A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#
# As an example, let's visualize the how the values of sepal width in the flowers dataset are distributed. We can use the **plt.hist** function to create a histogram.

# %%
# Load data into  a Pandas DataFrame
flowers_df = sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width);

# %% [markdown]
# We can immediately see that values of sepal width fall in the range 2.0-4.5, and around 35 values are in the range 2.9-3.1, which seems to be the largest bin.

# %% [markdown]
# ### Controlling the Size and Number of Bins
#
# We can control the number of bins, or the size of each bin using the **bins** argument.

# %%
# Specifying the number of bins
plt.hist(flowers_df.sepal_width, bins = 5)
# Out:
# (array([11., 46., 68., 21.,  4.]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <BarContainer object of 5 artists>)

# %%
import numpy as np

# Specifying the boundaries of each bin
plt.hist(flowers_df.sepal_width, bins =  np.arange(2, 5, 0.5));

# %% [markdown]
# ### Multiple Histograms
#
# Similar to line charts, we can draw multiple histograms in a single chart. We can reduce the opacity of each histogram, so the bars of one histogram don't hide the bars for others.
#
# Let's draw seperate histograms for each species of flowers.

# %%
setosa_df = flowers_df[flowers_df.species == "setosa"]
versicolor_df = flowers_df[flowers_df.species == "versicolor"]
virginica_df = flowers_df[flowers_df.species == "virginica"]

# %%
setosa_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
plt.hist(setosa_df.sepal_width, alpha = 0.6, bins = np.arange(2, 5, 0.25))
plt.hist(versicolor_df.sepal_width, alpha = 0.6, bins = np.arange(2, 5, 0.25))

plt.legend(["Setosa", "Versicolor"])

# %% [markdown]
# We can also stack multiple histograms on top of one another.

# %%
plt.title("Distribution of Sepal Width")

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins = np.arange(2, 5, 0.25), 
         stacked = True);

plt.legend(["Setosa", "Versicolor", "Virginica"])

# %%
plt.title("Distribution of Sepal Width")

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins = np.arange(2, 5, 0.25), 
         stacked = False);

plt.legend(["Setosa", "Versicolor", "Virginica"])

# %% [markdown]
# ## Bar Chart
#
# Bar chart are quite similar to line chart i.e. They show a sequence of values, howover a bar is shown for each value, rather than points connected by line.

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, oranges)
plt.plot(years, oranges, "o--r")
plt.title("Yields of Oranges")
# Out:
# Text(0.5, 1.0, 'Yields of Oranges')

# %% [markdown]
# Like histograms, bars can also be stacked on top of one another. We can use the **bottom** argument to **plt.bar** achive this.

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom = apples)

plt.xlabel("Years")
plt.ylabel("Apples and Oranges")

plt.title("Yields of Apples and Oranges")

plt.legend(["Apples", "Oranges"])

# %% [markdown]
# ### Bar Plots with Averages
#
# Let's look at another sample dataset included with Seaborn, called "tips". The dataset contains information about the sex, time of day, total bill and tip amount for customers visiting a restaurant over a week.

# %%
tips_df = sns.load_dataset("tips")

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
bill_avg_df = tips_df.groupby("day")[["total_bill"]].mean()

# %%
bill_avg_df
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(bill_avg_df.index, bill_avg_df.total_bill)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# We might want to draw a bar chart to visualize how the average bill amount varies across different days of the weeks. One way to do this  would be to compute the day-wise averages and then use **plt.bar** (try it as an exercise).
#
# Howover since this is a very common use case, the Seaborn library provides a **barplot** function which can automatically compute average.

# %%
sns.barplot(x = "day", y = "total_bill", data = tips_df);

# %% [markdown]
# The lines cutting each bar represent the amount of variation in the es. Fvaluor instance, it seems like the variation in the total bill was quite high on Friday, and lower on Saturday.
#
# We can also specify a **hue** argument to compare bar plots side-by-side based on a third feature e.g sex.

# %%
sns.barplot(x = "day", y = "total_bill", hue = "sex", data = tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# You can make the bars horizontal simply by switching the axes.

# %%
sns.barplot(x = "total_bill", y = "day", hue = "sex", data = tips_df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## Heatmap
#
# A heatmap is used to visualize 2-dimensional data like a matrix or a table using colors. The best way to undertand it is by looking at an example. We'll use another sample dataset from Seaborn, called "flights", to visualize monthly passenger footfal an an airport over 12 years.

# %%
sns.load_dataset("flights")
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.plot(sns.load_dataset("flights").passengers)

# %%
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")

# %%
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# **flights_df** is a matrix with one row for each month and one column of each year. The values in the matrix show the number of passengers (in thousands) that visted the airport in a specific month of a specific year. We can use the **sns.heatmap** function to visualize the footfall at the airport.

# %%
plt.title("No. of Passengers (1000s)")
sns.heatmap(flights_df)
# Out:
# <AxesSubplot:title={'center':'No. of Passengers (1000s)'}, xlabel='year', ylabel='month'>

# %% [markdown]
# The brighter colors indicate a higher footfall at the airport. By looking at the graph, we can infer two things:
#
# + The footfall at the airport in any given year tends to be the highest around July&August.
# + The footfall at the airport in any given month tends to grow year by year
#
# We can also display the actual values in each block by specifying **annot = True** and use the **cmap** argumant to change the color palette.

# %%
plt.title("No. of Passengers (1000s)")
sns.heatmap(flights_df, fmt = "d", annot = True, cmap = "Blues")
# Out:
# <AxesSubplot:title={'center':'No. of Passengers (1000s)'}, xlabel='year', ylabel='month'>

# %%
plt.title("No. of Passengers (1000s)")
sns.heatmap(flights_df, fmt = "d", annot = True, cmap = "Reds")
# Out:
# <AxesSubplot:title={'center':'No. of Passengers (1000s)'}, xlabel='year', ylabel='month'>

# %%
plt.title("No. of Passengers (1000s)")
sns.heatmap(flights_df, fmt = "d", annot = True, cmap = "Greens")
# Out:
# <AxesSubplot:title={'center':'No. of Passengers (1000s)'}, xlabel='year', ylabel='month'>

# %% [markdown]
# Learn more: https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# ## Images
#
# Matplotlib can also be used to display images. Let's get an image from the anywhere.
#
# Before an image can be displayed, it has to be read into memory using the PIL module.

# %%
from PIL import Image

# %%
img = Image.open("images.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=289x175 at 0x21ADC1191C0>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# An image loaded using PIL is simply a 3-dimesional numpy array containing pixel intensities for the red, green & blue (RGB) channels of the image. We can convert the image imto an array using **np.array**.

# %%
img_array = np.array(img)

# %%
img_array.shape
# Out:
# (175, 289, 3)

# %%
img_array
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# We can display the PIL image using **plt.imshow**.

# %%
plt.imshow(img);

# %% [markdown]
# We can turn off axes & grid lines and show a title using the relevant functions.

# %%
plt.grid(False)
plt.title("Numbers of Collection")
plt.axis("off")
plt.imshow(img);

# %% [markdown]
# To display a part of the image, we can simply select a sice from the numpy array.

# %%
plt.grid(False)
plt.axis("off")
plt.imshow(img_array[:101, 0:101])

# %% [markdown]
# ## Plotting Multiple Charts in A Grid
#
# Maptlotlib and Seaborn also support plotting multiple charts in a grid using **plt.subplots**, which returns a set of axes that can be used for plotting.
#
# Here's a single grid showing the different types of charts we've convered this tutorial.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(2, 3, figsize = (20, 10))

# Use the axes for plotting
axes[0, 0].plot(years, oranges, "o--r")
axes[0, 0].plot(years, apples, "s-b")
axes[0, 0].set_xlabel("Years")
axes[0, 0].set_ylabel("Yield (tons per hectare)")
axes[0, 0].set_title("Crop yields")
axes[0, 0].legend(["Oranges", "Aples"])

# Pass the axes into seaborn
axes[0, 1].set_title("Sepal length vs. width")
sns.scatterplot(x = flowers_df.sepal_length, 
                y = flowers_df.sepal_width, 
                hue = flowers_df.species, 
                c = 100, 
                ax = axes[0, 1])

# Use the axes for plotting
axes[0, 2].set_title("Distribution of Sepal Width")
axes[0, 2].hist([setosa_df.sepal_width, 
         versicolor_df.sepal_width, 
         virginica_df.sepal_width],
         bins = np.arange(2, 5, 0.25), 
         stacked = True)

axes[0, 2].legend(["Setoda", "Versicolor", "Virginica"])

# Pass the axes into seaborn
axes[1, 0].set_title("Restaurant Bills")
sns.barplot(x = "day", 
            y = "total_bill", 
            hue = "sex", 
            data = tips_df, 
            ax = axes[1, 0])

# Pass the axes into seaborn
axes[1, 1].set_title("Flight Traffic")
sns.heatmap(flights_df, 
            cmap = "Blues", 
            annot = False, 
            ax = axes[1, 1])

# Plot an image using the axes
axes[1, 2].set_title("Number of Collection")
axes[1, 2].imshow(img)
axes[1, 2].grid(False)
axes[1, 2].set_xticks([])
axes[1, 2].set_yticks([])

plt.tight_layout(pad = 2)

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
axes.shape
# Out:
# (2, 3)

# %% [markdown]
# ## Pair Plots with Seaborn
#
# Seaborn also provides a helper function **sns.pairplot** to automatically plot different types of charts for pairs of features within a dataframe.

# %%
sns.pairplot(flowers_df, hue = "species")

# %%
sns.pairplot(tips_df, hue = "sex")
